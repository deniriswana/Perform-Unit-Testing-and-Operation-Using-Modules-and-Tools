# %% [markdown]
# Function Arguments and Parameters
#
# Arguments that can be passed to the function
#
# As the value to be entered when the function is called, there are 2 types of arguments
#
# * Keyword arguments, namely arguments that are accompanied by an identifier or parameter name that is explicitly mentioned. This includes if we pass values ​​through a dictionary that are preceded by two signs * and (**)

# %%
def timetable(date, month, year):
  departure = "departure schedule is date {} month {} year {}".format(date, month, year)
  return departure

# %%
timetable (date=4, month='March', year= 2022)
# Out:
# 'departure schedule is date 4 month March year 2022'

# %%
timetable(**{'date':8, 'month':'June','year':2022})
# Out:
# 'departure schedule is date 8 month June year 2022'

# %% [markdown]
# * Positional Arguments, namely Arguments other than Keyword Arguments, if we send variables that are interable, they must be preceded by a *

# %%
def timetable(date, month, year):
  departure = "departure schedule is date {} month {} year {}".format(date, month, year)
  return departure

# %%
timetable(4,'March',2022)
# Out:
# 'departure schedule is date 4 month March year 2022'

# %%
timetable(*(4,'March',2022))
# Out:
# 'departure schedule is date 4 month March year 2022'

# %%
def study (date, month, year,day):
  progres = "Im learning python date {}  month {} year {} day {} ".format(date,  month, year, day)
  return progres

# %%
study(*(4,'April', 2022,'Monday'))
# Out:
# 'Im learning python date 4  month April year 2022 day Monday '

# %%
study(**{'date': 11, 'month':'April','year':2022,'day':'Monday'})
# Out:
# 'Im learning python date 11  month April year 2022 day Monday '

# %% [markdown]
# syntax prefix * is used as an iterable marker in Python, while prefix ** is used as a container/dictionary marker
#
# Function Parameter Order
#
# There are 5 possible sequences of functions in python:
# * Positional or keyword : You can write arguments as keyword arguments or positional arguments
#
# * Positional Only : You specify that certain arguments can only be placed in certain positions. This is done by declaring the main position followed by a / .
#
# * Keyword Only : You specify that certain arguments must be supplied in the form of keyword arguments. This is done by declaring one var-positional argument followed by an *.
#
# * Var-positional and var-keyword : You specify that there are several positional arguments and there are several keyword arguments that you will process. var-positional is marked with a prefix*(iterable) and var-keyword is marked with a prefix**(dictionary)
#
# * If there are dynamic positional arguments and dynamic keyword arguments, the order is positional arguments first, then keyword arguments

# %%
def info(*arg, **kunci_dict):
    for i in arg:
      print("position argument{}".format(i))
    for key, value in kunci_dict.items():
      print("keyword argument {}:{}". format(key,value))

# %%
info(1)
# Out:
# position argument1

# %%
info(1, key = 2, value = 3)
# Out:
# position argument1
# keyword argument key:2
# keyword argument value:3

# %%
def notice (*arg, **key_dict):
    for comments in arg:
      print("position argument{}".format(comments))
    for key, value in key_dict.items():
      print("keyword argument {}:{}". format(key,value))

# %%
notice(100, key = 200, value = 'succes')
# Out:
# position argument100
# keyword argument key:200
# keyword argument value:succes

# %% [markdown]
# Anonymous Function
#
# * Anonymous functions are not declared like other functions with the def keyword, but instead use the lambda keyword
#
# * A lambada function can accept any number of arguments, but returns only one expression value
#
# * Lambda functions cannot load other commands or expressions. for example can not print.
#
# * Lambda functions are self-contained, have their own namespace, and cannot access any values ​​other than those in parameter lists and global variables

# %%
addition = lambda number1, number2 : number1 + number2
subtraction = lambda num1, num2 : num1 - num2
multiplication = lambda number1, number2 : number1 * number2
divided = lambda number1, number2 : number1 / number2
squared = lambda number1, number2 : number1 ** number2

# %%
print("Additional Result {}" .format(addition (1,2)))
print("Subtraction Result {}" .format(subtraction(4,2)))
print("Multiplication Result {}" .format(multiplication(7,3)))
print("Divided Result {}" .format(divided (2,2)))
print("Squared Result {}" .format(squared (2,4)))
# Out:
# Additional Result 3
# Subtraction Result 2
# Multiplication Result 21
# Divided Result 1.0
# Squared Result 16
