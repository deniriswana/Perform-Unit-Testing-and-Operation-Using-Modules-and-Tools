# %% [markdown]
# ###Random Library
# - randint() is an inbuilt function of the random module in Python3. The random module gives access to various useful functions and one of them being able to generate random numbers, which is randint().
# - Syntax: randint(start, end)

# %%
from random import randint

# %%
randint(start, end)

# %%
for i in range(5):
  print(f"Random num {i} is {randint(1,5)}")
# Out:
# Random num 0 is 2
# Random num 1 is 1
# Random num 2 is 5
# Random num 3 is 5
# Random num 4 is 5

# %%
for i in range(10):
  print("Random num {} is {}".format(i,randint(1,10)))
# Out:
# Random num 0 is 5
# Random num 1 is 6
# Random num 2 is 9
# Random num 3 is 9
# Random num 4 is 5
# Random num 5 is 10
# Random num 6 is 5
# Random num 7 is 2
# Random num 8 is 9
# Random num 9 is 10

# %% [markdown]
# ###Task

# %%
for i in range(1,11):
  print(f"Nomor acak ke-{i} adalah {randint(100,200)}")
# Out:
# Nomor acak ke-1 adalah 162
# Nomor acak ke-2 adalah 161
# Nomor acak ke-3 adalah 110
# Nomor acak ke-4 adalah 154
# Nomor acak ke-5 adalah 115
# Nomor acak ke-6 adalah 118
# Nomor acak ke-7 adalah 163
# Nomor acak ke-8 adalah 115
# Nomor acak ke-9 adalah 119
# Nomor acak ke-10 adalah 170
