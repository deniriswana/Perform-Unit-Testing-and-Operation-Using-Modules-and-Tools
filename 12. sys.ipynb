# %% [markdown]
# ###sys

# %%
import sys

# %%
a = float(input("Enter a number: "))
b = float(input("Enter a number to divided by: "))

try:
  print(f"The answer is {a/b}")
except:
  print(sys.exc_info() [0])
  print("This did not work. Did you try to divide by zero or something")
else:
  print("You succesfully used the division feature in Python")
finally:
  print("Thank you for for Playing")
# Out:
# Enter a number: 9
# Enter a number to divided by: 0
# <class 'ZeroDivisionError'>
# This did not work. Did you try to divide by zero or something
# Thank you for for Playing
